# %%
# %config Completer.use_jedi = False

from utils import *
from parallel import to_run, to_run_for_MvsT

import numpy as np
from matplotlib import pyplot as plt
import importlib
from multiprocessing import Pool
from tqdm.notebook import tqdm
import pickle


from ising_model import SimulateMH
BC = SimulateMH.BoundaryCondition

# %%
plt.rcParams["figure.facecolor"] = "white"
plt.rcParams["figure.dpi"] = 72
plt.rcParams["figure.figsize"] = [12,8]

# %%
pool = Pool(32)

# %% [raw]
# with open("dumps/32x32-rangeT-rand.pkl","rb") as f:
#     results_rand = pickle.load(f)
# N=M=32

# %% [raw]
# with open("dumps/32x32-rangeT-const.pkl","rb") as f:
#     results_rand = pickle.load(f)

# %% [raw]
# results = results_rand

# %%
relaxation_time_normalized(1)*16
# Out:
# 7031.25

# %%
scale = 200
times = 1000
N = 32
H = 0.003
steps = int(1e7)
Ts = np.linspace(1.2,3,scale*times).reshape((times, scale))

results = []
for Ts1 in tqdm(Ts):
    runs = len(Ts1)
    res = pool.starmap(to_run_for_MvsT, 
            zip(*(np.arange(runs),
                      [steps]*runs, # steps
                      Ts1, # temperature
                      [N]*runs, # lattice size
                      [N]*runs, # lattice size
                      [1]*runs, # frequency
                      np.random.randint(0,10**8, runs), # seed
                      [BC.Periodic]*runs, # bc
                    [False]*runs, # return_engine
                    ["constant"]*runs, # init
                  [H]*runs # H field
                      ))
        )
    results+= res
results_p = results

results = []
for Ts1 in tqdm(Ts):
    runs = len(Ts1)
    res = pool.starmap(to_run_for_MvsT, 
            zip(*(np.arange(runs),
                      [steps]*runs, # steps
                      Ts1, # temperature
                      [N]*runs, # lattice size
                      [N]*runs, # lattice size
                      [1]*runs, # frequency
                      np.random.randint(0,10**8, runs), # seed
                      [BC.Periodic]*runs, # bc
                    [False]*runs, # return_engine
                    ["constant"]*runs, # init
                  [-H]*runs # H field
                      ))
        )
    results+= res
    
results_n = results
# Out:
# ...
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
beep()
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
with open("32x32-rangeMT-const-1e7steps-withH.pkl", "wb") as f:
    pickle.dump((results_p, results_n), f)

# %%
Ts = np.array([T for T, _, M, _, E, _ in results])
meanMs_n = np.array([M[-2] for T, _, M, _, E, _ in results_n])
meanMs_p = np.array([M[-2] for T, _, M, _, E, _ in results_p])

# %%
# plt.errorbar(Ts, np.abs(meanMs),yerr=errMs)
plt.scatter(Ts, (meanMs_p), s=0.3, marker="o", alpha=0.1)
plt.scatter(Ts, (-meanMs_n), s=0.3, marker="o",  alpha=0.1)
plt.minorticks_on()
# plt.grid(which="both")
# for t, m in zip(Ts, np.abs(meanMs)):
#     plt.gca().annotate(f'{t:0.2f}', (t,m))

# %%
Ts_tot = np.concatenate([Ts,Ts])

Ms_tot = np.concatenate([meanMs_p, -meanMs_n])
c_tot = np.concatenate([np.zeros_like(Ts), np.ones_like(Ts)])
perm = np.random.permutation(len(Ts_tot))
Ts_tot = Ts_tot[perm]
Ms_tot = Ms_tot[perm]
c_tot = c_tot[perm]

# %%
perm
# Out:
# array([375927, 277428, 154581, ..., 212069, 177909, 181400])

# %%
plt.scatter(Ts_tot, Ms_tot, c=-c_tot, s=0.3, alpha=0.1, cmap="coolwarm")

# %%
Ts_tot.shape
# Out:
# (400000,)

# %%
print(len(meanMs[meanMs<-900]), len(meanMs[meanMs>+900]))
# Out:
# 45572 46255

# %%
len(results[0][3])
# Out:
# 10000

# %%
T1 = 1
dT = 0.1
plt.figure()
plt.hist(meanMs[(T1-dT < Ts) & (T1+dT > Ts)], bins=30);

# %% [raw]
# with open("dumps/32x32-rangeT-rand.pkl","wb") as f:
#     pickle.dump(results, f)

# %% [raw]
# with open("dumps/32x32-rangeT-const.pkl","wb") as f:
#     pickle.dump(results, f)
